# %%
# %matplotlib inline
import numpy
from pylab import *

# %%
cd /mnt/slice
# Out:
# /mnt/slice

# %%
dist1 = numpy.loadtxt('SRR1976948.dist', skiprows=1, delimiter=',')
plot(dist1[:,0], dist1[:,1])
axis(ymax=10000, xmax=1000)
title('k-mer abundance distribution')

# %%
dist2 = numpy.loadtxt('SRR1976948.readdist')
plot(dist2[:,0], dist2[:,1])
axis(xmax=150)
title('read coverage distribution')
