# %%
# %matplotlib inline
import numpy
from pylab import *

# %%
cd /mnt/quant
# Out:
# /mnt/quant

# %%
ls
# Out:
# SRR1976948.abundtrim.subset.pe.1.fq    SRR1977249.abundtrim.subset.pe.fq.gz@
# SRR1976948.abundtrim.subset.pe.2.fq    SRR1977249.quant/
# SRR1976948.abundtrim.subset.pe.fq.gz@  SRR1977249.quant.counts
# SRR1976948.quant/                      gather-counts.py
# SRR1976948.quant.counts                metagG.ffn@
# SRR1977249.abundtrim.subset.pe.1.fq    transcript_index/
# SRR1977249.abundtrim.subset.pe.2.fq

# %%
ls *.counts
# Out:
# SRR1976948.quant.counts  SRR1977249.quant.counts

# %%
counts1 = [ x.split()[1] for x in open('SRR1976948.quant.counts')]
counts1 = [ float(x) for x in counts1[1:] ]
counts1 = numpy.array(counts1)

# %%
counts2 = [ x.split()[1] for x in open('SRR1977249.quant.counts')]
counts2 = [ float(x) for x in counts2[1:] ]
counts2 = numpy.array(counts2)

# %%
plot(counts1, counts2, '*')
